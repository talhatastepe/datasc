# %%
# Bu dosya 5, 6, 7 ve 8. sayfalarındaki örnekleri içeriyor.

a_str = "ali"
b_int = 5
print(f"'{a_str}' değişkeninin tipi: {type(a_str)}")
print(f"{b_int} değişkeninin tipi: {type(b_int)}")


liste1 = [1, 3, 3, 5, 4, 5, 4, "ali", "canan"]
print(f"\nOrijinal Liste: {liste1}")
print(f"Listenin ilk elemanı (index 0): {liste1[0]}")
print(f"Listenin eleman sayısı: {len(liste1)}")


liste2 = [1, 3, 3, 5, 4, 5, 4]
print(f"\nSıralanacak Liste: {liste2}")
liste2.sort()  # Listeyi yerinde sıralar
print(f"Sıralanmış Liste: {liste2}")

liste2.append(25) 
print(f"25 eklendikten sonra liste: {liste2}")


demet = ("ali", "ayşe")
print(f"\nDemetimiz: {demet}")
print(f"'ali' elemanının demetteki indeksi: {demet.index('ali')}")


print("\n--- Fonksiyon Tanımlama (Sayfa 6) ---")


def selam():
    print("Merhaba, bu parametresiz bir fonksiyondur.")

selam() 


def selam_gotur(isim):
    print(f"Merhaba, {isim}")

selam_gotur("Ahmet")


def topla(a, b):
    c = a + b
    return c

sonuc = topla(3, 5)
print(f"Toplama fonksiyonunun sonucu: {sonuc}")


print("\n--- Lambda Fonksiyonu (Sayfa 7) ---")


def kare_al(x):
    return x*x


kare_lambda = lambda x: x*x

print(f"Normal fonksiyon ile 4'ün karesi: {kare_al(4)}")
print(f"Lambda fonksiyonu ile 4'ün karesi: {kare_lambda(4)}")


print("\n--- Modül Kullanımı (Sayfa 8) ---")

[cite_start]import math
[cite_start]import random 


kok_al = math.sqrt(16)
print(f"16 sayısının karekökü (math.sqrt): {kok_al}")


[cite_start]rastgele_sayi = random.randint(1, 100)
print(f"1 ile 100 arasında rastgele bir sayı: {rastgele_sayi}")
